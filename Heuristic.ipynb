# %%
import stanza

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

import json 

import re
# Out:
# C:\Users\Delbert\AppData\Roaming\Python\Python36\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Data Preprocessing

# %%
#Read files and convert string to dictionary
df = pd.read_csv("data_tier-1_sample.csv")
df["cohort"] = df["cohort"].apply(json.loads)

# %%
#Create inclusion and exclusion criteria columns
df["inclusion"] = ["None"]*len(df)
df["exclusion"] = ["None"]*len(df)

cohort = df["cohort"]
for x in range(len(cohort)):
    df["inclusion"][x] = cohort[x]["inclusion"]
    df["exclusion"][x] = cohort[x]["exclusion"]

# %%
def clean_text(x):
    x = re.sub("-", "", x)
    x = re.sub("\(", " ", x)
    x = re.sub("\)", " ", x)
    return x
    
df["query"] = df["query"].apply(clean_text)

# %% [markdown]
# # spaCy

# %% [markdown]
# ### Dependency Parsing

# %%
import spacy
from spacy.lang.en import English

# %%
nlp = spacy.load("en_core_web_sm")
tok_nlp = English()
tokenizer = nlp.Defaults.create_tokenizer(tok_nlp)
# tok = tokenizer(df["query"][1])

# %%
def convert(inclusion, exclusion, query):
    doc = nlp(query)
    criterias = inclusion + exclusion

    for criteria in criterias: 
        criteria = clean_text(criteria)
        convert_dict = {}
        for token in doc:
            convert_dict[token.text] = token.i
        criteria = tokenizer(criteria)  
        start = convert_dict[str(criteria[0])]
        span = doc[start : start + len(criteria)]

        with doc.retokenize() as retokenizer:
            retokenizer.merge(span)

    return doc

# %%
inclusion_tree = []
exclusion_tree = []
errors = []

for x in range(len(df)):
    try:
        doc = convert(df["inclusion"][x], df["exclusion"][x], df["query"][x])
        inclusion = [clean_text(criteria) for criteria in df["inclusion"][x]]
        exclusion = [clean_text(criteria) for criteria in df["exclusion"][x]]
        for token in doc:
            temp_dict_i = {}
            temp_dict_e = {}
            if token.text in inclusion:
                temp_dict_i["Text"] = token.text
                temp_dict_i["POS"] = token.pos_
                temp_dict_i["DEP"] = token.dep_
                temp_dict_i["Head"] = token.head.text
                if token.i >= 1:
                    temp_dict_i["Left Neighbor"] = str(token.nbor(-1))
                    if token.i >= 2:
                        temp_dict_i["Left 2 Neighbor"] = str(token.nbor(-2))
                        if token.i >= 3:
                            temp_dict_i["Left 3 Neighbor"] = str(token.nbor(-3))
                        else:
                            temp_dict_i["Left 3 Neighbor"] = "None"
                    else:
                        temp_dict_i["Left 2 Neighbor"] = "None"
                else:
                    temp_dict_i["Left Neighbor"] = "None"
                inclusion_tree.append(temp_dict_i)
            if token.text in exclusion:
                temp_dict_e["Text"] = token.text
                temp_dict_e["POS"] = token.pos_
                temp_dict_e["DEP"] = token.dep_
                temp_dict_e["Head"] = token.head.text
                if token.i >= 1:
                    temp_dict_e["Left Neighbor"] = str(token.nbor(-1))
                    if token.i >= 2:
                        temp_dict_e["Left 2 Neighbor"] = str(token.nbor(-2))
                        if token.i >= 3:
                            temp_dict_e["Left 3 Neighbor"] = str(token.nbor(-3))
                        else:
                            temp_dict_e["Left 3 Neighbor"] = "None"
                    else:
                        temp_dict_e["Left 2 Neighbor"] = "None"
                else:
                    temp_dict_e["Left Neighbor"] = "None"
                exclusion_tree.append(temp_dict_e)
    except:
        errors.append(x)

# %%
len(errors)/len(df)
# Out:
# 0.016304347826086956

# %%
inclusion = pd.DataFrame(inclusion_tree)
inclusion["Left 2 Neighbor"] = inclusion["Left 2 Neighbor"].astype(str)
inclusion["Left 2 Neighbor"] = inclusion["Left 2 Neighbor"].str.replace("age.*", "age")
exclusion = pd.DataFrame(exclusion_tree)
exclusion["Left 2 Neighbor"] = exclusion["Left 2 Neighbor"].astype(str)
exclusion["Left 2 Neighbor"] = exclusion["Left 2 Neighbor"].str.replace("age.*", "age")

# %% [markdown]
# ### Inclusion

# %%
g = sns.countplot(inclusion["DEP"])
plt.xticks(rotation=-90)
plt.title("Inclusion Common Dependencies")
# Out:
# Text(0.5, 1.0, 'Inclusion Common Dependencies')

# %%
g = sns.countplot(inclusion["Head"])
plt.xticks(rotation=-90)
plt.xlim((0,20))
plt.title("Inclusion Common Heads")
# Out:
# Text(0.5, 1.0, 'Inclusion Common Heads')

# %%
def create_df(df, columns, head, by):
    df_a = df.groupby(by = columns).first().sort_values(by = by, ascending=False).head(head)
    df_b = df.groupby(by = columns).count().sort_values(by = by, ascending=False).head(head)
    df_neighbors = pd.concat([df_a, df_b], axis=1).drop(labels = ["Head"], axis = 1)
    return df_neighbors

inclusion_summary = create_df(inclusion, ["Left Neighbor", "Left 2 Neighbor", "Left 3 Neighbor"], 30, "Left Neighbor")
inclusion_summary
# Out:
#                                                                                                                             Text  \
# Left Neighbor Left 2 Neighbor Left 3 Neighbor
# with          people          should                                                                   ventricular septal defect
#               patients        me                                                                   hyperplasia of maxillary bone
#                               for                                                                                         age<68
#               age             with                                                                                comedonal acne
#                               for                                                                            dysplasia of vagina
# vs            new york        in                                                                                         seattle
#               boston          in                                                                                         chicago
#               chicago         in                                                                                       san diego
#               san diego       in                                                                                       san diego
#               seattle         in                                                                                          boston
# to            predispositions genetic                                                                     oropharyngeal aspirate
# taking        currently       disorder of pericardium                                             4methylumbelliferyl chitobiose
#                               communicating hydrocephalus                                                             ofatumumab
#                               concussion with loss of consciousness                                                   calcitriol
#                               contracture of joint of finger                                                        perflubutane
#                               cyclothymia                                                                           mecamylamine
#                               decubitus ulcer of ankle                          10r 10methyl3 6methylpyridin3yl 9,10,11,12tet...
#                               degeneration of lumbosacral intervertebral disc                      n 5'phosphopyridoxyl lalanine
#                               dermatitis caused by radiation                                                          ofatumumab
#                               fracture of radius and ulna                                                monopotassium phosphate
#                               disorder of tooth development                                                               ags004
#                               dissection of internal carotid artery                                                    lidocaine
#                               ehlersdanlos syndrome                            3{6[ 8hydroxyquinoline2carbonyl amino]2thiophe...
#                               endometriosis of uterus                                                                rolofylline
#                               factor v leiden mutation                                                     s,spropylthiocysteine
#                               cholesteatoma                                                              5'sethyl5'thioadenosine
#                               fracture of thoracic spine                                            octyl betadgalactopyranoside
#                               ganglion of wrist                                     5 3,3dihydroxypropeny 3methoxybenzene1,2diol
#                               closed fracture of shaft of tibia                                                         cp122721
#                               basal cell carcinoma of scalp                                                           belinostat
#
#                                                                                  POS  \
# Left Neighbor Left 2 Neighbor Left 3 Neighbor
# with          people          should                                            NOUN
#               patients        me                                               PROPN
#                               for                                              PROPN
#               age             with                                             PROPN
#                               for                                              PROPN
# vs            new york        in                                               PROPN
#               boston          in                                               PROPN
#               chicago         in                                               PROPN
#               san diego       in                                               PROPN
#               seattle         in                                               PROPN
# to            predispositions genetic                                           VERB
# taking        currently       disorder of pericardium                           NOUN
#                               communicating hydrocephalus                       NOUN
#                               concussion with loss of consciousness             NOUN
#                               contracture of joint of finger                    NOUN
#                               cyclothymia                                       NOUN
#                               decubitus ulcer of ankle                           NUM
#                               degeneration of lumbosacral intervertebral disc   NOUN
#                               dermatitis caused by radiation                    NOUN
#                               fracture of radius and ulna                       NOUN
#                               disorder of tooth development                    PROPN
#                               dissection of internal carotid artery             NOUN
#                               ehlersdanlos syndrome                              NUM
#                               endometriosis of uterus                           NOUN
#                               factor v leiden mutation                          NOUN
#                               cholesteatoma                                      NUM
#                               fracture of thoracic spine                        NOUN
#                               ganglion of wrist                                  NUM
#                               closed fracture of shaft of tibia                PROPN
#                               basal cell carcinoma of scalp                     NOUN
#
#                                                                                   DEP  \
# Left Neighbor Left 2 Neighbor Left 3 Neighbor
# with          people          should                                             pobj
#               patients        me                                                 pobj
#                               for                                                pobj
#               age             with                                               pobj
#                               for                                                pobj
# vs            new york        in                                                 pobj
#               boston          in                                                 pobj
#               chicago         in                                                 pobj
#               san diego       in                                                 pobj
#               seattle         in                                                 pobj
# to            predispositions genetic                                             acl
# taking        currently       disorder of pericardium                            dobj
#                               communicating hydrocephalus                        dobj
#                               concussion with loss of consciousness              dobj
#                               contracture of joint of finger                     dobj
#                               cyclothymia                                        dobj
#                               decubitus ulcer of ankle                           ROOT
#                               degeneration of lumbosacral intervertebral disc    dobj
#                               dermatitis caused by radiation                     dobj
#                               fracture of radius and ulna                        dobj
#                               disorder of tooth development                      dobj
#                               dissection of internal carotid artery              dobj
#                               ehlersdanlos syndrome                              ROOT
#                               endometriosis of uterus                            dobj
#                               factor v leiden mutation                           dobj
#                               cholesteatoma                                    advmod
#                               fracture of thoracic spine                         dobj
#                               ganglion of wrist                                  ROOT
#                               closed fracture of shaft of tibia                  dobj
#                               basal cell carcinoma of scalp                      dobj
#
#                                                                                Text  \
# Left Neighbor Left 2 Neighbor Left 3 Neighbor
# with          people          should                                            156
#               patients        me                                                160
#                               for                                               781
#               age             with                                              780
#                               for                                                40
# vs            new york        in                                                  4
#               boston          in                                                  6
#               chicago         in                                                 12
#               san diego       in                                                 10
#               seattle         in                                                  8
# to            predispositions genetic                                            40
# taking        currently       disorder of pericardium                             4
#                               communicating hydrocephalus                         4
#                               concussion with loss of consciousness               4
#                               contracture of joint of finger                      4
#                               cyclothymia                                         8
#                               decubitus ulcer of ankle                            8
#                               degeneration of lumbosacral intervertebral disc     8
#                               dermatitis caused by radiation                      4
#                               fracture of radius and ulna                         8
#                               disorder of tooth development                       8
#                               dissection of internal carotid artery               8
#                               ehlersdanlos syndrome                              16
#                               endometriosis of uterus                             4
#                               factor v leiden mutation                            8
#                               cholesteatoma                                       8
#                               fracture of thoracic spine                          4
#                               ganglion of wrist                                   4
#                               closed fracture of shaft of tibia                   4
#                               basal cell carcinoma of scalp                       4
#
#                                                                                POS  \
# Left Neighbor Left 2 Neighbor Left 3 Neighbor
# with          people          should                                           156
#               patients        me                                               160
#                               for                                              781
#               age             with                                             780
#                               for                                               40
# vs            new york        in                                                 4
#               boston          in                                                 6
#               chicago         in                                                12
#               san diego       in                                                10
#               seattle         in                                                 8
# to            predispositions genetic                                           40
# taking        currently       disorder of pericardium                            4
#                               communicating hydrocephalus                        4
#                               concussion with loss of consciousness              4
#                               contracture of joint of finger                     4
#                               cyclothymia                                        8
#                               decubitus ulcer of ankle                           8
#                               degeneration of lumbosacral intervertebral disc    8
#                               dermatitis caused by radiation                     4
#                               fracture of radius and ulna                        8
#                               disorder of tooth development                      8
#                               dissection of internal carotid artery              8
#                               ehlersdanlos syndrome                             16
#                               endometriosis of uterus                            4
#                               factor v leiden mutation                           8
#                               cholesteatoma                                      8
#                               fracture of thoracic spine                         4
#                               ganglion of wrist                                  4
#                               closed fracture of shaft of tibia                  4
#                               basal cell carcinoma of scalp                      4
#
#                                                                                DEP
# Left Neighbor Left 2 Neighbor Left 3 Neighbor
# with          people          should                                           156
#               patients        me                                               160
#                               for                                              781
#               age             with                                             780
#                               for                                               40
# vs            new york        in                                                 4
#               boston          in                                                 6
#               chicago         in                                                12
#               san diego       in                                                10
#               seattle         in                                                 8
# to            predispositions genetic                                           40
# taking        currently       disorder of pericardium                            4
#                               communicating hydrocephalus                        4
#                               concussion with loss of consciousness              4
#                               contracture of joint of finger                     4
#                               cyclothymia                                        8
#                               decubitus ulcer of ankle                           8
#                               degeneration of lumbosacral intervertebral disc    8
#                               dermatitis caused by radiation                     4
#                               fracture of radius and ulna                        8
#                               disorder of tooth development                      8
#                               dissection of internal carotid artery              8
#                               ehlersdanlos syndrome                             16
#                               endometriosis of uterus                            4
#                               factor v leiden mutation                           8
#                               cholesteatoma                                      8
#                               fracture of thoracic spine                         4
#                               ganglion of wrist                                  4
#                               closed fracture of shaft of tibia                  4
#                               basal cell carcinoma of scalp                      4

# %% [markdown]
# ### Exclusion

# %%
g = sns.countplot(exclusion["DEP"])
plt.xticks(rotation=-90)
plt.title("Exclusion Common Dependencies")
# Out:
# Text(0.5, 1.0, 'Exclusion Common Dependencies')

# %%
g = sns.countplot(exclusion["Head"])
plt.xticks(rotation=-90)
plt.xlim((0,30))
plt.title("Exclusion Common Heads")
# Out:
# Text(0.5, 1.0, 'Exclusion Common Heads')

# %%
exclusion_summary = create_df(exclusion, ["Left Neighbor", "Left 2 Neighbor", "Left 3 Neighbor"], 50, "Left Neighbor")
exclusion_summary
# Out:
#                                                                                                                                                           Text  \
# Left Neighbor Left 2 Neighbor                            Left 3 Neighbor
# with          diagnosed                                  newly                                                                      generalized osteoarthritis
# taking        but                                        arecoline                                                                                    uk500001
#                                                          benfluorex                                                                                  mosapride
#                                                          bromowillardiine                                                                            mosapride
#                                                          carbamic acid                                                           odecyl hydrogen thiocarbonate
#                                                          dihydroorotic acid                                                                          carprofen
#                                                          eht899                                                                                         idd594
#                                                          etacrynic acid                                               imidazo[2,1a]isoquinoline2carbohydrazide
#                                                          gammaglutamyl[s 2iodobenzyl cysteinyl]glycine                           odecyl hydrogen thiocarbonate
#                                                          gefitinib                                                                                   osanetant
#                                                          indoramin                                                                                      mk0557
#                                                          iso24                                                                   phosphoglycolohydroxamic acid
#                                                          lproline, 1[ 2s 3mercapto2methyl1oxopropyl]4 ph...                                           uk500001
#                                                          nmethyl1 2thiophen2ylphenyl methanamine                                                    lacidipine
#                                                          ozarelix                                                                phosphoglycolohydroxamic acid
#                                                          perazine                                                                                       abxpth
#                                                          phenserine                                                                              isocarboxazid
#                                                          rimacalib                                                        1 3methylphenyl 1hbenzimidazol5amine
#                                                          sadenosyl1,8diamino3thiooctane                                                             lacidipine
#                                                          atrazine glutathione conjugate                                                          penicillamine
#                                                          alks 29                                                                                alloisoleucine
#                                                          telotristat                                                                               4oxoretinol
#                                                          albiglutide                                                  imidazo[2,1a]isoquinoline2carbohydrazide
#               arachnoiditis                              with                                                            [hydroxy 3phenylpropyl amino]methanol
#               asteatotic eczema                          with                                                                                 trifluoroethanol
#               atypical absence seizure                   with                                                                                       zebularine
#               basal cell carcinoma of truncal skin       with                                                9hydroxy6 3hydroxypropyl 4 2methoxyphenyl pyrr...
#               benign secondary renovascular hypertension with                                                                                 dihydroetorphine
#               biliary stricture                          with                                                                                        voglibose
#               but                                         2s,3s,4e,6e,8s,9s 3amino9methoxy2,6,8trimethyl...  sulfamic acid 2,3o 1methylethylidene 4,5osulfo...
#                                                           4r 7aza7,8dihydrolimonene                                                       pentavalent antimony
#                                                          2 3,4dihydro3oxo2hbenzo[b][1,4]thiazin2yl nhydr...                                     alloisoleucine
#                                                          2,6dimethyl1 3ethyl5isoxazolyl]propanyl 4...                2'monophosphoadenosine5'diphosphate
#                                                          2thioethenamine                                                                             osanetant
#                                                          3,5diiodothyropropionic acid                                                                    m0002
#                                                          3phenyl1,2propandiol                                                                         dalanine
#                                                          3phenylpropionic acid                                2r 2 {9 1methylethyl 6[ 4pyridin2ylbenzyl ami...
#                                                          4[ 1s 1 3fluoro4methoxyphenyl 2 2methoxy5nitrop...                                      isocarboxazid
#                                                          5 2,5dichlorophenyl 2furoic acid                             11trans13trans15cisoctadecatrienoic acid
#                                                          6carbamimidoyl4 3hydroxy2methylbenzoylamino nap...                            strontium chloride sr89
#                                                          savolitinib                                         sulfamic acid 2,3o 1methylethylidene 4,5osulfo...
#                                                          jnj40346527                                                                              azithromycin
#                                                          tiotropium                                                                                     mk0557
#               open wound of face                         with                                                                                 trifluoroethanol
#               oral lichen planus                         with                                                 6s 2amino6 3'methoxybiphenyl3yl 3,6dimethyl5,...
#               paraphimosis                               with                                                                                      diridavumab
#               pneumoconiosis caused by silica            with                                                                                           su9516
#               pneumonia caused by mycoplasma pneumoniae  with                                                methyl 4{[ {[ 2r,5s 5{[ 2s 2 aminomethyl pyrro...
#               preterm rupture of membranes               with                                                                                   quinaldic acid
#               reactive airways dysfunction syndrome      with                                                2[3,4dihydroxy2hydroxymethyl5 2hydroxynonyl te...
#
#                                                                                                                POS  \
# Left Neighbor Left 2 Neighbor                            Left 3 Neighbor
# with          diagnosed                                  newly                                                NOUN
# taking        but                                        arecoline                                            NOUN
#                                                          benfluorex                                            ADV
#                                                          bromowillardiine                                      ADV
#                                                          carbamic acid                                        NOUN
#                                                          dihydroorotic acid                                   NOUN
#                                                          eht899                                              PUNCT
#                                                          etacrynic acid                                        ADP
#                                                          gammaglutamyl[s 2iodobenzyl cysteinyl]glycine        NOUN
#                                                          gefitinib                                             ADJ
#                                                          indoramin                                            NOUN
#                                                          iso24                                                NOUN
#                                                          lproline, 1[ 2s 3mercapto2methyl1oxopropyl]4 ph...   NOUN
#                                                          nmethyl1 2thiophen2ylphenyl methanamine              NOUN
#                                                          ozarelix                                             NOUN
#                                                          perazine                                             NOUN
#                                                          phenserine                                           NOUN
#                                                          rimacalib                                             NUM
#                                                          sadenosyl1,8diamino3thiooctane                       NOUN
#                                                          atrazine glutathione conjugate                       NOUN
#                                                          alks 29                                              NOUN
#                                                          telotristat                                           NUM
#                                                          albiglutide                                           ADP
#               arachnoiditis                              with                                                PROPN
#               asteatotic eczema                          with                                                 NOUN
#               atypical absence seizure                   with                                                 NOUN
#               basal cell carcinoma of truncal skin       with                                                  NUM
#               benign secondary renovascular hypertension with                                                 NOUN
#               biliary stricture                          with                                                 NOUN
#               but                                         2s,3s,4e,6e,8s,9s 3amino9methoxy2,6,8trimethyl...    NUM
#                                                           4r 7aza7,8dihydrolimonene                           NOUN
#                                                          2 3,4dihydro3oxo2hbenzo[b][1,4]thiazin2yl nhydr...   NOUN
#                                                          2,6dimethyl1 3ethyl5isoxazolyl]propanyl 4...    NUM
#                                                          2thioethenamine                                       ADJ
#                                                          3,5diiodothyropropionic acid                        PROPN
#                                                          3phenyl1,2propandiol                                 NOUN
#                                                          3phenylpropionic acid                                NOUN
#                                                          4[ 1s 1 3fluoro4methoxyphenyl 2 2methoxy5nitrop...   NOUN
#                                                          5 2,5dichlorophenyl 2furoic acid                     NOUN
#                                                          6carbamimidoyl4 3hydroxy2methylbenzoylamino nap...  PROPN
#                                                          savolitinib                                           NUM
#                                                          jnj40346527                                          NOUN
#                                                          tiotropium                                           NOUN
#               open wound of face                         with                                                 NOUN
#               oral lichen planus                         with                                                  NUM
#               paraphimosis                               with                                                 NOUN
#               pneumoconiosis caused by silica            with                                                 NOUN
#               pneumonia caused by mycoplasma pneumoniae  with                                                  NUM
#               preterm rupture of membranes               with                                                PROPN
#               reactive airways dysfunction syndrome      with                                                  NUM
#
#                                                                                                                   DEP  \
# Left Neighbor Left 2 Neighbor                            Left 3 Neighbor
# with          diagnosed                                  newly                                                  nsubj
# taking        but                                        arecoline                                               dobj
#                                                          benfluorex                                            advmod
#                                                          bromowillardiine                                      advmod
#                                                          carbamic acid                                           dobj
#                                                          dihydroorotic acid                                      dobj
#                                                          eht899                                                  dobj
#                                                          etacrynic acid                                        advmod
#                                                          gammaglutamyl[s 2iodobenzyl cysteinyl]glycine           dobj
#                                                          gefitinib                                               dobj
#                                                          indoramin                                               dobj
#                                                          iso24                                                   dobj
#                                                          lproline, 1[ 2s 3mercapto2methyl1oxopropyl]4 ph...      dobj
#                                                          nmethyl1 2thiophen2ylphenyl methanamine                 dobj
#                                                          ozarelix                                                dobj
#                                                          perazine                                                dobj
#                                                          phenserine                                              dobj
#                                                          rimacalib                                               dobj
#                                                          sadenosyl1,8diamino3thiooctane                          dobj
#                                                          atrazine glutathione conjugate                          dobj
#                                                          alks 29                                                 dobj
#                                                          telotristat                                             dobj
#                                                          albiglutide                                           advmod
#               arachnoiditis                              with                                                    dobj
#               asteatotic eczema                          with                                                    dobj
#               atypical absence seizure                   with                                                    dobj
#               basal cell carcinoma of truncal skin       with                                                    ROOT
#               benign secondary renovascular hypertension with                                                    dobj
#               biliary stricture                          with                                                    pobj
#               but                                         2s,3s,4e,6e,8s,9s 3amino9methoxy2,6,8trimethyl...      ROOT
#                                                           4r 7aza7,8dihydrolimonene                              dobj
#                                                          2 3,4dihydro3oxo2hbenzo[b][1,4]thiazin2yl nhydr...      dobj
#                                                          2,6dimethyl1 3ethyl5isoxazolyl]propanyl 4...  npadvmod
#                                                          2thioethenamine                                         dobj
#                                                          3,5diiodothyropropionic acid                            dobj
#                                                          3phenyl1,2propandiol                                    dobj
#                                                          3phenylpropionic acid                                   ROOT
#                                                          4[ 1s 1 3fluoro4methoxyphenyl 2 2methoxy5nitrop...      dobj
#                                                          5 2,5dichlorophenyl 2furoic acid                        dobj
#                                                          6carbamimidoyl4 3hydroxy2methylbenzoylamino nap...      ROOT
#                                                          savolitinib                                             ROOT
#                                                          jnj40346527                                             dobj
#                                                          tiotropium                                              dobj
#               open wound of face                         with                                                    dobj
#               oral lichen planus                         with                                                  dative
#               paraphimosis                               with                                                    dobj
#               pneumoconiosis caused by silica            with                                                    dobj
#               pneumonia caused by mycoplasma pneumoniae  with                                                    intj
#               preterm rupture of membranes               with                                                    dobj
#               reactive airways dysfunction syndrome      with                                                    dobj
#
#                                                                                                              Text  \
# Left Neighbor Left 2 Neighbor                            Left 3 Neighbor
# with          diagnosed                                  newly                                                 80
# taking        but                                        arecoline                                              8
#                                                          benfluorex                                             4
#                                                          bromowillardiine                                       4
#                                                          carbamic acid                                          8
#                                                          dihydroorotic acid                                     8
#                                                          eht899                                                 8
#                                                          etacrynic acid                                         8
#                                                          gammaglutamyl[s 2iodobenzyl cysteinyl]glycine          8
#                                                          gefitinib                                              8
#                                                          indoramin                                              4
#                                                          iso24                                                  8
#                                                          lproline, 1[ 2s 3mercapto2methyl1oxopropyl]4 ph...     8
#                                                          nmethyl1 2thiophen2ylphenyl methanamine                8
#                                                          ozarelix                                               8
#                                                          perazine                                               8
#                                                          phenserine                                             8
#                                                          rimacalib                                              8
#                                                          sadenosyl1,8diamino3thiooctane                         8
#                                                          atrazine glutathione conjugate                         8
#                                                          alks 29                                                3
#                                                          telotristat                                            8
#                                                          albiglutide                                            8
#               arachnoiditis                              with                                                   2
#               asteatotic eczema                          with                                                   2
#               atypical absence seizure                   with                                                   2
#               basal cell carcinoma of truncal skin       with                                                   2
#               benign secondary renovascular hypertension with                                                   2
#               biliary stricture                          with                                                   2
#               but                                         2s,3s,4e,6e,8s,9s 3amino9methoxy2,6,8trimethyl...     8
#                                                           4r 7aza7,8dihydrolimonene                             8
#                                                          2 3,4dihydro3oxo2hbenzo[b][1,4]thiazin2yl nhydr...     3
#                                                          2,6dimethyl1 3ethyl5isoxazolyl]propanyl 4...     8
#                                                          2thioethenamine                                        8
#                                                          3,5diiodothyropropionic acid                           8
#                                                          3phenyl1,2propandiol                                   8
#                                                          3phenylpropionic acid                                  8
#                                                          4[ 1s 1 3fluoro4methoxyphenyl 2 2methoxy5nitrop...     8
#                                                          5 2,5dichlorophenyl 2furoic acid                       8
#                                                          6carbamimidoyl4 3hydroxy2methylbenzoylamino nap...     8
#                                                          savolitinib                                            8
#                                                          jnj40346527                                            8
#                                                          tiotropium                                             4
#               open wound of face                         with                                                   2
#               oral lichen planus                         with                                                   2
#               paraphimosis                               with                                                   2
#               pneumoconiosis caused by silica            with                                                   2
#               pneumonia caused by mycoplasma pneumoniae  with                                                   2
#               preterm rupture of membranes               with                                                   2
#               reactive airways dysfunction syndrome      with                                                   2
#
#                                                                                                              POS  \
# Left Neighbor Left 2 Neighbor                            Left 3 Neighbor
# with          diagnosed                                  newly                                                80
# taking        but                                        arecoline                                             8
#                                                          benfluorex                                            4
#                                                          bromowillardiine                                      4
#                                                          carbamic acid                                         8
#                                                          dihydroorotic acid                                    8
#                                                          eht899                                                8
#                                                          etacrynic acid                                        8
#                                                          gammaglutamyl[s 2iodobenzyl cysteinyl]glycine         8
#                                                          gefitinib                                             8
#                                                          indoramin                                             4
#                                                          iso24                                                 8
#                                                          lproline, 1[ 2s 3mercapto2methyl1oxopropyl]4 ph...    8
#                                                          nmethyl1 2thiophen2ylphenyl methanamine               8
#                                                          ozarelix                                              8
#                                                          perazine                                              8
#                                                          phenserine                                            8
#                                                          rimacalib                                             8
#                                                          sadenosyl1,8diamino3thiooctane                        8
#                                                          atrazine glutathione conjugate                        8
#                                                          alks 29                                               3
#                                                          telotristat                                           8
#                                                          albiglutide                                           8
#               arachnoiditis                              with                                                  2
#               asteatotic eczema                          with                                                  2
#               atypical absence seizure                   with                                                  2
#               basal cell carcinoma of truncal skin       with                                                  2
#               benign secondary renovascular hypertension with                                                  2
#               biliary stricture                          with                                                  2
#               but                                         2s,3s,4e,6e,8s,9s 3amino9methoxy2,6,8trimethyl...    8
#                                                           4r 7aza7,8dihydrolimonene                            8
#                                                          2 3,4dihydro3oxo2hbenzo[b][1,4]thiazin2yl nhydr...    3
#                                                          2,6dimethyl1 3ethyl5isoxazolyl]propanyl 4...    8
#                                                          2thioethenamine                                       8
#                                                          3,5diiodothyropropionic acid                          8
#                                                          3phenyl1,2propandiol                                  8
#                                                          3phenylpropionic acid                                 8
#                                                          4[ 1s 1 3fluoro4methoxyphenyl 2 2methoxy5nitrop...    8
#                                                          5 2,5dichlorophenyl 2furoic acid                      8
#                                                          6carbamimidoyl4 3hydroxy2methylbenzoylamino nap...    8
#                                                          savolitinib                                           8
#                                                          jnj40346527                                           8
#                                                          tiotropium                                            4
#               open wound of face                         with                                                  2
#               oral lichen planus                         with                                                  2
#               paraphimosis                               with                                                  2
#               pneumoconiosis caused by silica            with                                                  2
#               pneumonia caused by mycoplasma pneumoniae  with                                                  2
#               preterm rupture of membranes               with                                                  2
#               reactive airways dysfunction syndrome      with                                                  2
#
#                                                                                                              DEP
# Left Neighbor Left 2 Neighbor                            Left 3 Neighbor
# with          diagnosed                                  newly                                                80
# taking        but                                        arecoline                                             8
#                                                          benfluorex                                            4
#                                                          bromowillardiine                                      4
#                                                          carbamic acid                                         8
#                                                          dihydroorotic acid                                    8
#                                                          eht899                                                8
#                                                          etacrynic acid                                        8
#                                                          gammaglutamyl[s 2iodobenzyl cysteinyl]glycine         8
#                                                          gefitinib                                             8
#                                                          indoramin                                             4
#                                                          iso24                                                 8
#                                                          lproline, 1[ 2s 3mercapto2methyl1oxopropyl]4 ph...    8
#                                                          nmethyl1 2thiophen2ylphenyl methanamine               8
#                                                          ozarelix                                              8
#                                                          perazine                                              8
#                                                          phenserine                                            8
#                                                          rimacalib                                             8
#                                                          sadenosyl1,8diamino3thiooctane                        8
#                                                          atrazine glutathione conjugate                        8
#                                                          alks 29                                               3
#                                                          telotristat                                           8
#                                                          albiglutide                                           8
#               arachnoiditis                              with                                                  2
#               asteatotic eczema                          with                                                  2
#               atypical absence seizure                   with                                                  2
#               basal cell carcinoma of truncal skin       with                                                  2
#               benign secondary renovascular hypertension with                                                  2
#               biliary stricture                          with                                                  2
#               but                                         2s,3s,4e,6e,8s,9s 3amino9methoxy2,6,8trimethyl...    8
#                                                           4r 7aza7,8dihydrolimonene                            8
#                                                          2 3,4dihydro3oxo2hbenzo[b][1,4]thiazin2yl nhydr...    3
#                                                          2,6dimethyl1 3ethyl5isoxazolyl]propanyl 4...    8
#                                                          2thioethenamine                                       8
#                                                          3,5diiodothyropropionic acid                          8
#                                                          3phenyl1,2propandiol                                  8
#                                                          3phenylpropionic acid                                 8
#                                                          4[ 1s 1 3fluoro4methoxyphenyl 2 2methoxy5nitrop...    8
#                                                          5 2,5dichlorophenyl 2furoic acid                      8
#                                                          6carbamimidoyl4 3hydroxy2methylbenzoylamino nap...    8
#                                                          savolitinib                                           8
#                                                          jnj40346527                                           8
#                                                          tiotropium                                            4
#               open wound of face                         with                                                  2
#               oral lichen planus                         with                                                  2
#               paraphimosis                               with                                                  2
#               pneumoconiosis caused by silica            with                                                  2
#               pneumonia caused by mycoplasma pneumoniae  with                                                  2
#               preterm rupture of membranes               with                                                  2
#               reactive airways dysfunction syndrome      with                                                  2

# %% [raw]
# with open('inclusion.pickle', 'wb') as b:
#     pickle.dump(inclusion,b)
#
# with open('exclusion.pickle', 'wb') as b:
#     pickle.dump(exclusion,b)

# %% [markdown]
# ### Neighboring

# %%
query = df["query"][0]
query
# Out:
# 'show me patients with hyperplasia of maxillary bone but not anemia due to chronic blood loss or transjugular intrahepatic portosystemic shunt'

# %% [markdown]
# # Forming Heuristic Rules

# %%
import pickle

inclusion = pickle.load(open("inclusion.pickle",'rb'))
exclusion = pickle.load(open("exclusion.pickle",'rb'))

# %%
inclusion
# Out:
#                                                  Text    POS   DEP  \
# 0                       hyperplasia of maxillary bone  PROPN  pobj
# 1                           ventricular septal defect   NOUN  pobj
# 2     abnormal findings on diagnostic imaging of lung   NOUN  conj
# 3                                              age<68  PROPN  pobj
# 4                                      comedonal acne  PROPN  pobj
# ...                                               ...    ...   ...
# 2999                                          age>=76  PROPN  pobj
# 3000                                 neoplasm of skin   NOUN  pobj
# 3001            late effect of motor vehicle accident   NOUN  pobj
# 3002                           portal vein thrombosis   NOUN  pobj
# 3003                                     facial spasm   NOUN  conj
#
#                            Head Left Neighbor            Left 2 Neighbor
# 0                          with          with                   patients
# 1                          with          with                     people
# 2     ventricular septal defect           and  ventricular septal defect
# 3                          with          with                   patients
# 4                          with          with                     age<68
# ...                         ...           ...                        ...
# 2999                       with          with                   patients
# 3000                       with          with                    age>=76
# 3001                       with          with                   patients
# 3002                       with          with                     people
# 3003     portal vein thrombosis           and     portal vein thrombosis
#
# [3004 rows x 6 columns]

# %%
exclusion
# Out:
#                                                Text   POS   DEP  \
# 0                  anemia due to chronic blood loss  NOUN  conj
# 1     transjugular intrahepatic portosystemic shunt  NOUN  conj
# 2                headache following lumbar puncture  VERB  prep
# 3                                           age<=75  NOUN  pobj
# 4                                          sex=male  NOUN  ROOT
# ...                                             ...   ...   ...
# 3269                                   pansinusitis  VERB  conj
# 3270              autologous bone marrow transplant  NOUN  conj
# 3271      carcinoma of lower lobe, bronchus or lung  NOUN  pobj
# 3272                                         age>98  NOUN  pobj
# 3273                                     sex=female  NOUN  conj
#
#                                   Head
# 0        hyperplasia of maxillary bone
# 1     anemia due to chronic blood loss
# 2                               tested
# 3                            excluding
# 4                             sex=male
# ...                                ...
# 3269                          patients
# 3270                      pansinusitis
# 3271                               for
# 3272                         excluding
# 3273                            age>98
#
# [3274 rows x 4 columns]

# %%
for query in df["query"][0:5]:
    print(query, "\n")
# Out:
# show me patients with hyperplasia of maxillary bone but not anemia due to chronic blood loss or transjugular intrahepatic portosystemic shunt
#
# should people with ventricular septal defect and abnormal findings on diagnostic imaging of lung be tested for headache following lumbar puncture excluding age<=75 and sex=male
#
# can you show me the recovery rate for patients with age<68 with comedonal acne and hypoplasia of the optic nerve currently taking n 1benzyl3,3,3trifluoro2,2dihydroxypropyl acetamide but not 3oxooctanoic acid  2oxotetrahydrofuran3yl amide
#
# genetic predispositions to oropharyngeal aspirate
#
# can you show me the recovery rate for patients with age>=7 with sensory hearing loss and quadriparesis not currently taking 5 2,5dichlorophenyl 2furoic acid but taking 11trans13trans15cisoctadecatrienoic acid

# %%
print(len(df))
# Out:
# 1656
